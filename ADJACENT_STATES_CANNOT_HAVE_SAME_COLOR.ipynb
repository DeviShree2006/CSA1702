# %% [markdown]
# <a href="https://colab.research.google.com/github/DeviShree2006/CSA1702/blob/main/ADJACENT_STATES_CANNOT_HAVE_SAME_COLOR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
colors = ["Red", "Green", "Blue"]

for stateA in colors:
    for stateB in colors:

        # Constraint: Adjacent states cannot have same color
        if stateA != stateB:
            print("State A =", stateA,
                  "State B =", stateB)
# Out:
# State A = Red State B = Green
# State A = Red State B = Blue
# State A = Green State B = Red
# State A = Green State B = Blue
# State A = Blue State B = Red
# State A = Blue State B = Green
