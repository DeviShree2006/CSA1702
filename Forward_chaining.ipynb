# %% [markdown]
# <a href="https://colab.research.google.com/github/DeviShree2006/CSA1702/blob/main/Forward_chaining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Forward Chaining Example

# Initial fact
facts = {"Study"}

# Rule: If Study then Pass
if "Study" in facts:
    facts.add("Pass")

# Print inferred facts
print("Knowledge Base:")
for fact in facts:
    print(fact)
# Out:
# Knowledge Base:
# Study
# Pass
