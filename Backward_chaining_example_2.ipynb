# %% [markdown]
# <a href="https://colab.research.google.com/github/DeviShree2006/CSA1702/blob/main/Backward_chaining_example_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Backward Chaining Example

# Known facts
facts = {"Study"}

# Rule: Pass requires Study
rules = {
    "Pass": "Study"
}

# Goal
goal = "Pass"

print("Goal:", goal)

if goal in rules:
    required_fact = rules[goal]
    print("Need to prove:", required_fact)

    if required_fact in facts:
        print("Fact found:", required_fact)
        print("Goal Proved")
    else:
        print("Goal Cannot Be Proved")
else:
    print("No rule available")
# Out:
# Goal: Pass
# Need to prove: Study
# Fact found: Study
# Goal Proved
