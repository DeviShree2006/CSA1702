# %% [markdown]
# <a href="https://colab.research.google.com/github/DeviShree2006/CSA1702/blob/main/Temperature_and_Humidity_program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
temperature = int(input())

humidity = int(input())

if temperature > 35 and humidity > 60:
    print("Fan Speed High")

elif temperature > 35:
    print("Fan Speed Medium")

else:
    print("OFF")
# Out:
# 20
# 40
# OFF
